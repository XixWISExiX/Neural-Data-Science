# %% [markdown]
# This file is associated with lecture 22
#
# # Install FSL for Preprocessing fMRI
#
# Link: https://fsl.fmrib.ox.ac.uk/fsl/docs/#/install/index
#
# ### NOTE: if you need to analyze temporal differences (time differences) in images, do this before the preprocessing

# %%
# !python ~/Downloads/fslinstaller.py
# Out:
# FSL installer version: 3.15.2
# Press CTRL+C at any time to cancel installation
# Installation log file: /tmp/fslinstaller_vmu7k9zr.log
#
# Installing FSL implies agreement with the terms of the FSL license - if you
# do not agree with these terms, you can cancel the installation by pressing
# CTRL+C. You can view the license at
# https://fsl.fmrib.ox.ac.uk/fsl/docs/#/license
#
# During the installation process, please note that some system details will
# be automatically sent to the FSL development team. These details are extremely
# basic and cannot be used in any way to identify individual users. If you do not
# want any information to be sent, please cancel this installation by pressing
# CTRL+C, and re-run the installer with the --skip_registration option.
#
# FSL 6.0.7.15 selected for installation
#
# Where do you want to install FSL?
# Press enter to install to the default location [/home/joshua/fsl]
#
# FSL installation directory [/home/joshua/fsl]:
# ...

# %% [markdown]
# open the applicatoin via the two following commands
#
# `source ~/.profile`
#
# `fsl`
#
# anat.nii.gz is MRI file (x, y, z)
# func.nii.gz is fMRI file (x, y, z, t)
#
# ---
#
# Now use the FSL application and open anat file in FSLeyes.
#
# Then Create the Preprocessed data with "BET Brain Extraction" (simple)
#
# And check if it's good via FEAT fMRI analysis (more complex)

# %%
# Import the requred Packages
import os
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import nibabel as nib
# from google.colab import drive
# drive.mount('/content/drive')
# Load some anatomical MRI data (Available to download in https://github.com/lukassnoek/NI-edu/blob/master/NI-edu/fMRI-introduction/week_1/anat.nii.gz)
mri_file = '../../datasets/fMRI/anat_brain.nii.gz' # Preprocessed data
img = nib.load(mri_file)
print(type(img))
print(img.shape)
# Out:
# <class 'nibabel.nifti1.Nifti1Image'>
# (240, 240, 220)

# %%
img_data = img.get_fdata()
# Plot a slice of the MRI scan.
mid_slice_x = img_data[119, :, :]
print(mid_slice_x.shape)
plt.imshow(mid_slice_x.T, cmap='gray', origin='lower')
plt.xlabel('First axis')
plt.ylabel('Second axis')
plt.colorbar(label='Signal intensity')
plt.show()
# Out:
# (240, 220)
